# %% [markdown]
# Import neccessary libraries

# %%
import pandas as pd
import numpy as np
import yfinance as yf

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit



import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# --------------
# Data taken from 2019-2009 (20 Year Period)
#
# 2020 will only be presented once testing is finalized.

# %%
#Downloading of data from Yahoo Finance which will be used for model training
end = '2019-12-31'
start = '1999-01-02'

trainingData = yf.download('^GSPC', start=start, end=end)
trainingData.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1999-01-04  1229.229980  1248.810059  1219.099976  1228.099976  1228.099976
# 1999-01-05  1228.099976  1246.109985  1228.099976  1244.780029  1244.780029
# 1999-01-06  1244.780029  1272.500000  1244.780029  1272.339966  1272.339966
# 1999-01-07  1272.339966  1272.339966  1257.680054  1269.729980  1269.729980
# 1999-01-08  1269.729980  1278.239990  1261.819946  1275.089966  1275.089966
#
#                Volume
# Date
# 1999-01-04  877000000
# 1999-01-05  775000000
# 1999-01-06  986900000
# 1999-01-07  863000000
# 1999-01-08  937800000

# %%
#Downloading of data from Yahoo Finance which will be used for model testing
end = '2021-01-31'
start = '2020-01-02'

testingData = yf.download('^GSPC', start=start, end=end)
testingData.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3257.850098
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3234.850098
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3246.280029
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3237.179932
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3253.050049
#
#                 Volume
# Date
# 2020-01-02  3458250000
# 2020-01-03  3461290000
# 2020-01-06  3674070000
# 2020-01-07  3420380000
# 2020-01-08  3720890000

# %%
#Prediction will take place on Adj Close price, therefore we must isolate Adj Close.
trainprice = trainingData['Adj Close']
trainData = trainprice.values

testprice = testingData['Adj Close']
testData = testprice.values

# %%
trainData
# Out:
# array([1228.09997559, 1244.7800293 , 1272.33996582, ..., 3239.90991211,
#        3240.02001953, 3221.29003906])

# %% [markdown]
# Plotting of High vs Low

# %%
plt.figure(figsize=(10,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().yaxis.set_major_locator(mdates.DayLocator(interval=200))

plt.plot(trainingData.index, trainingData['Adj Close'], label='Train Data Actual Adj Close')
plt.plot(testingData.index, testingData['Adj Close'], label='Test Data Actual Adj Close')
plt.xlabel('Date')
plt.ylabel('USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %%
sc = MinMaxScaler(feature_range=(0,1))
trainDataScaled = sc.fit_transform(trainData.reshape(-1, 1))
testDataScaled = sc.fit_transform(testData.reshape(-1, 1))

# %%
n_steps = 20

xTrain, yTrain = [], []

for i in range(n_steps, len(trainDataScaled)):
    xTrain.append(trainDataScaled[i-n_steps:i, 0])
    yTrain.append(trainDataScaled[i, 0])
      
xTrain, yTrain = np.array(xTrain), np.array(yTrain)
xTrain = np.reshape(xTrain, (xTrain.shape[0], xTrain.shape[1], 1))

# %%
#LSTM Model

model = Sequential()

#Layer 1
model.add(LSTM(units=200,return_sequences=True,input_shape=(xTrain.shape[1], 1)))
model.add(Dropout(0.2))
#Layer 2
model.add(LSTM(units=200,return_sequences=True))
model.add(Dropout(0.2))
#Layer 3
model.add(LSTM(units=200,return_sequences=True))
model.add(Dropout(0.2))
#Layer 4
model.add(LSTM(units=200, return_sequences=False))
model.add(Dropout(0.2))
#Layer 5
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error', metrics=[RootMeanSquaredError(), MeanAbsoluteError()])
model.summary()

#Early stopping parameters to stop unnecessary training
earlyStopping = EarlyStopping(
    monitor='val_root_mean_squared_error',
    patience=15,
    mode='min',
    min_delta = 0.000001
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 20, 200)           161600
#
#  dropout_16 (Dropout)        (None, 20, 200)           0
#
#  lstm_17 (LSTM)              (None, 20, 200)           320800
#
#  dropout_17 (Dropout)        (None, 20, 200)           0
#
#  lstm_18 (LSTM)              (None, 20, 200)           320800
#
#  dropout_18 (Dropout)        (None, 20, 200)           0
#
#  lstm_19 (LSTM)              (None, 200)               320800
#
#  dropout_19 (Dropout)        (None, 200)               0
#
#  dense_4 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 1,124,201
# Trainable params: 1,124,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Method to plot the training metric vs validation mertric
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
#Evaluation of model to confirm if parameters set above are valid
eval = model.evaluate(xTrain, yTrain)
# Out:
# 165/165 [==============================] - 3s 14ms/step - loss: 0.1598 - root_mean_squared_error: 0.3998 - mean_absolute_error: 0.3355

# %%
len(xTrain)
# Out:
# 5262

# %%
log = model.fit(
    xTrain,
    yTrain,
    epochs=100,
    batch_size=128, 
    validation_split = 0.25, 
    verbose=1, 
    callbacks=[earlyStopping], 
    shuffle=False)
plot_metric(log, 'root_mean_squared_error')
# Out:
# Epoch 1/100
# 31/31 [==============================] - 8s 142ms/step - loss: 0.0084 - root_mean_squared_error: 0.0917 - mean_absolute_error: 0.0693 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0945 - val_mean_absolute_error: 0.0749
# Epoch 2/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0133 - root_mean_squared_error: 0.1152 - mean_absolute_error: 0.0916 - val_loss: 0.1094 - val_root_mean_squared_error: 0.3307 - val_mean_absolute_error: 0.3121
# Epoch 3/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0096 - root_mean_squared_error: 0.0977 - mean_absolute_error: 0.0866 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995 - val_mean_absolute_error: 0.0753
# Epoch 4/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0108 - root_mean_squared_error: 0.1039 - mean_absolute_error: 0.0872 - val_loss: 0.1294 - val_root_mean_squared_error: 0.3597 - val_mean_absolute_error: 0.3381
# Epoch 5/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - mean_absolute_error: 0.0909 - val_loss: 0.1330 - val_root_mean_squared_error: 0.3647 - val_mean_absolute_error: 0.3445
# Epoch 6/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0083 - root_mean_squared_error: 0.0910 - mean_absolute_error: 0.0775 - val_loss: 0.0581 - val_root_mean_squared_error: 0.2411 - val_mean_absolute_error: 0.2239
# Epoch 7/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.0027 - root_mean_squared_error: 0.0521 - mean_absolute_error: 0.0432 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0412 - val_mean_absolute_error: 0.0323
# Epoch 8/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0030 - root_mean_squared_error: 0.0544 - mean_absolute_error: 0.0422 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0505 - val_mean_absolute_error: 0.0447
# Epoch 9/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - mean_absolute_error: 0.0296 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0486 - val_mean_absolute_error: 0.0386
# Epoch 10/100
# 31/31 [==============================] - 4s 140ms/step - loss: 4.5678e-04 - root_mean_squared_error: 0.0214 - mean_absolute_error: 0.0163 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352 - val_mean_absolute_error: 0.0295
# Epoch 11/100
# 31/31 [==============================] - 4s 140ms/step - loss: 3.9535e-04 - root_mean_squared_error: 0.0199 - mean_absolute_error: 0.0151 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0474 - val_mean_absolute_error: 0.0367
# Epoch 12/100
# 31/31 [==============================] - 4s 143ms/step - loss: 4.3911e-04 - root_mean_squared_error: 0.0210 - mean_absolute_error: 0.0163 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335 - val_mean_absolute_error: 0.0255
# Epoch 13/100
# 31/31 [==============================] - 4s 144ms/step - loss: 6.3094e-04 - root_mean_squared_error: 0.0251 - mean_absolute_error: 0.0193 - val_loss: 7.5090e-04 - val_root_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0222
# Epoch 14/100
# 31/31 [==============================] - 4s 142ms/step - loss: 6.1210e-04 - root_mean_squared_error: 0.0247 - mean_absolute_error: 0.0192 - val_loss: 7.5536e-04 - val_root_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0224
# Epoch 15/100
# 31/31 [==============================] - 4s 146ms/step - loss: 6.3950e-04 - root_mean_squared_error: 0.0253 - mean_absolute_error: 0.0192 - val_loss: 7.5190e-04 - val_root_mean_squared_error: 0.0274 - val_mean_absolute_error: 0.0223
# Epoch 16/100
# 31/31 [==============================] - 5s 147ms/step - loss: 5.6996e-04 - root_mean_squared_error: 0.0239 - mean_absolute_error: 0.0184 - val_loss: 7.8654e-04 - val_root_mean_squared_error: 0.0280 - val_mean_absolute_error: 0.0230
# Epoch 17/100
# 31/31 [==============================] - 5s 148ms/step - loss: 6.0537e-04 - root_mean_squared_error: 0.0246 - mean_absolute_error: 0.0187 - val_loss: 6.9038e-04 - val_root_mean_squared_error: 0.0263 - val_mean_absolute_error: 0.0211
# Epoch 18/100
# 31/31 [==============================] - 4s 142ms/step - loss: 5.7315e-04 - root_mean_squared_error: 0.0239 - mean_absolute_error: 0.0184 - val_loss: 8.2059e-04 - val_root_mean_squared_error: 0.0286 - val_mean_absolute_error: 0.0236
# Epoch 19/100
# 31/31 [==============================] - 4s 143ms/step - loss: 6.5307e-04 - root_mean_squared_error: 0.0256 - mean_absolute_error: 0.0193 - val_loss: 8.0087e-04 - val_root_mean_squared_error: 0.0283 - val_mean_absolute_error: 0.0229
# Epoch 20/100
# 31/31 [==============================] - 4s 142ms/step - loss: 8.3616e-04 - root_mean_squared_error: 0.0289 - mean_absolute_error: 0.0223 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410 - val_mean_absolute_error: 0.0356
# Epoch 21/100
# 31/31 [==============================] - 4s 141ms/step - loss: 0.0011 - root_mean_squared_error: 0.0329 - mean_absolute_error: 0.0259 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0391 - val_mean_absolute_error: 0.0339
# Epoch 22/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.0013 - root_mean_squared_error: 0.0365 - mean_absolute_error: 0.0282 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0687 - val_mean_absolute_error: 0.0658
# Epoch 23/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0015 - root_mean_squared_error: 0.0387 - mean_absolute_error: 0.0321 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0444 - val_mean_absolute_error: 0.0394
# Epoch 24/100
# 31/31 [==============================] - 4s 143ms/step - loss: 5.6445e-04 - root_mean_squared_error: 0.0238 - mean_absolute_error: 0.0183 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0358 - val_mean_absolute_error: 0.0292
# Epoch 25/100
# 31/31 [==============================] - 4s 145ms/step - loss: 3.2818e-04 - root_mean_squared_error: 0.0181 - mean_absolute_error: 0.0138 - val_loss: 7.5429e-04 - val_root_mean_squared_error: 0.0275 - val_mean_absolute_error: 0.0224
# Epoch 26/100
# 31/31 [==============================] - 5s 147ms/step - loss: 4.3484e-04 - root_mean_squared_error: 0.0209 - mean_absolute_error: 0.0168 - val_loss: 4.9902e-04 - val_root_mean_squared_error: 0.0223 - val_mean_absolute_error: 0.0174
# Epoch 27/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - mean_absolute_error: 0.0278 - val_loss: 7.3280e-04 - val_root_mean_squared_error: 0.0271 - val_mean_absolute_error: 0.0217
# Epoch 28/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.0018 - root_mean_squared_error: 0.0420 - mean_absolute_error: 0.0361 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0655 - val_mean_absolute_error: 0.0630
# Epoch 29/100
# 31/31 [==============================] - 4s 144ms/step - loss: 0.0021 - root_mean_squared_error: 0.0459 - mean_absolute_error: 0.0383 - val_loss: 4.4508e-04 - val_root_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0162
# Epoch 30/100
# 31/31 [==============================] - 4s 145ms/step - loss: 6.7512e-04 - root_mean_squared_error: 0.0260 - mean_absolute_error: 0.0214 - val_loss: 5.0909e-04 - val_root_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.0171
# Epoch 31/100
# 31/31 [==============================] - 4s 144ms/step - loss: 5.5333e-04 - root_mean_squared_error: 0.0235 - mean_absolute_error: 0.0190 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0598 - val_mean_absolute_error: 0.0482
# Epoch 32/100
# 31/31 [==============================] - 5s 146ms/step - loss: 0.0016 - root_mean_squared_error: 0.0404 - mean_absolute_error: 0.0338 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712 - val_mean_absolute_error: 0.0688
# Epoch 33/100
# 31/31 [==============================] - 5s 147ms/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - mean_absolute_error: 0.0424 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0354 - val_mean_absolute_error: 0.0303
# Epoch 34/100
# 31/31 [==============================] - 5s 148ms/step - loss: 0.0011 - root_mean_squared_error: 0.0331 - mean_absolute_error: 0.0246 - val_loss: 6.1588e-04 - val_root_mean_squared_error: 0.0248 - val_mean_absolute_error: 0.0201
# Epoch 35/100
# 31/31 [==============================] - 5s 146ms/step - loss: 4.9504e-04 - root_mean_squared_error: 0.0222 - mean_absolute_error: 0.0174 - val_loss: 8.1467e-04 - val_root_mean_squared_error: 0.0285 - val_mean_absolute_error: 0.0213
# Epoch 36/100
# 31/31 [==============================] - 4s 142ms/step - loss: 3.0428e-04 - root_mean_squared_error: 0.0174 - mean_absolute_error: 0.0131 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0423 - val_mean_absolute_error: 0.0311
# Epoch 37/100
# 31/31 [==============================] - 4s 141ms/step - loss: 5.4951e-04 - root_mean_squared_error: 0.0234 - mean_absolute_error: 0.0180 - val_loss: 8.4839e-04 - val_root_mean_squared_error: 0.0291 - val_mean_absolute_error: 0.0248
# Epoch 38/100
# 31/31 [==============================] - 4s 142ms/step - loss: 6.9685e-04 - root_mean_squared_error: 0.0264 - mean_absolute_error: 0.0206 - val_loss: 6.8410e-04 - val_root_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0219
# Epoch 39/100
# 31/31 [==============================] - 4s 142ms/step - loss: 6.6400e-04 - root_mean_squared_error: 0.0258 - mean_absolute_error: 0.0199 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322 - val_mean_absolute_error: 0.0277
# Epoch 40/100
# 31/31 [==============================] - 4s 143ms/step - loss: 4.9596e-04 - root_mean_squared_error: 0.0223 - mean_absolute_error: 0.0177 - val_loss: 3.4104e-04 - val_root_mean_squared_error: 0.0185 - val_mean_absolute_error: 0.0138
# Epoch 41/100
# 31/31 [==============================] - 4s 143ms/step - loss: 5.0054e-04 - root_mean_squared_error: 0.0224 - mean_absolute_error: 0.0182 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0378 - val_mean_absolute_error: 0.0340
# Epoch 42/100
# 31/31 [==============================] - 4s 143ms/step - loss: 7.3955e-04 - root_mean_squared_error: 0.0272 - mean_absolute_error: 0.0227 - val_loss: 8.9912e-04 - val_root_mean_squared_error: 0.0300 - val_mean_absolute_error: 0.0251
# Epoch 43/100
# 31/31 [==============================] - 4s 145ms/step - loss: 0.0011 - root_mean_squared_error: 0.0328 - mean_absolute_error: 0.0278 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0652 - val_mean_absolute_error: 0.0631
# Epoch 44/100
# 31/31 [==============================] - 4s 142ms/step - loss: 0.0015 - root_mean_squared_error: 0.0386 - mean_absolute_error: 0.0325 - val_loss: 7.0983e-04 - val_root_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0213
# Epoch 45/100
# 31/31 [==============================] - 4s 146ms/step - loss: 5.6370e-04 - root_mean_squared_error: 0.0237 - mean_absolute_error: 0.0196 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0340 - val_mean_absolute_error: 0.0301
# Epoch 46/100
# 31/31 [==============================] - 4s 144ms/step - loss: 5.5666e-04 - root_mean_squared_error: 0.0236 - mean_absolute_error: 0.0195 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0440 - val_mean_absolute_error: 0.0383
# Epoch 47/100
# 31/31 [==============================] - 4s 145ms/step - loss: 6.3099e-04 - root_mean_squared_error: 0.0251 - mean_absolute_error: 0.0210 - val_loss: 8.9609e-04 - val_root_mean_squared_error: 0.0299 - val_mean_absolute_error: 0.0255
# Epoch 48/100
# 31/31 [==============================] - 4s 145ms/step - loss: 6.0186e-04 - root_mean_squared_error: 0.0245 - mean_absolute_error: 0.0201 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0438 - val_mean_absolute_error: 0.0376
# Epoch 49/100
# 31/31 [==============================] - 5s 145ms/step - loss: 6.1044e-04 - root_mean_squared_error: 0.0247 - mean_absolute_error: 0.0205 - val_loss: 8.1597e-04 - val_root_mean_squared_error: 0.0286 - val_mean_absolute_error: 0.0242
# Epoch 50/100
# 31/31 [==============================] - 5s 147ms/step - loss: 5.1933e-04 - root_mean_squared_error: 0.0228 - mean_absolute_error: 0.0183 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0385 - val_mean_absolute_error: 0.0315
# Epoch 51/100
# 31/31 [==============================] - 4s 144ms/step - loss: 5.7200e-04 - root_mean_squared_error: 0.0239 - mean_absolute_error: 0.0199 - val_loss: 8.3049e-04 - val_root_mean_squared_error: 0.0288 - val_mean_absolute_error: 0.0246
# Epoch 52/100
# 31/31 [==============================] - 4s 145ms/step - loss: 5.3133e-04 - root_mean_squared_error: 0.0231 - mean_absolute_error: 0.0183 - val_loss: 9.6981e-04 - val_root_mean_squared_error: 0.0311 - val_mean_absolute_error: 0.0239
# Epoch 53/100
# 31/31 [==============================] - 4s 144ms/step - loss: 6.4556e-04 - root_mean_squared_error: 0.0254 - mean_absolute_error: 0.0209 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0357 - val_mean_absolute_error: 0.0314
# Epoch 54/100
# 31/31 [==============================] - 4s 145ms/step - loss: 5.5094e-04 - root_mean_squared_error: 0.0235 - mean_absolute_error: 0.0187 - val_loss: 7.3145e-04 - val_root_mean_squared_error: 0.0270 - val_mean_absolute_error: 0.0203
# Epoch 55/100
# 31/31 [==============================] - 4s 145ms/step - loss: 6.5351e-04 - root_mean_squared_error: 0.0256 - mean_absolute_error: 0.0211 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0339 - val_mean_absolute_error: 0.0296

# %%
n_steps = 20

xTest = []
yTest = []

for i in range(n_steps, len(testDataScaled)):
    xTest.append(testDataScaled[i-n_steps:i, 0])
    yTest.append(testDataScaled[i, 0])
      
xTest, yTest = np.array(xTest), np.array(yTest)
xTest = np.reshape(xTest, (xTest.shape[0], xTest.shape[1], 1))

# %%
predictions = model.predict(xTest) #Prediction on 2020 Data using trained model
output = sc.inverse_transform(predictions)
rmse = np.sqrt(mean_squared_error(predictions, yTest)) #Calculating of RMSE
rmse
# Out:
# 8/8 [==============================] - 0s 16ms/step
# 0.07149176989454135

# %%
eval = model.evaluate(xTest, yTest) #Calculating of additional metrics (Loss, RMSE, MAE)
# Out:
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0051 - root_mean_squared_error: 0.0715 - mean_absolute_error: 0.0459

# %% [markdown]
# The following cells are the joining of the actual data + prediction into a single DF

# %%
df1 = pd.DataFrame(testingData['Adj Close']).astype(float)
df1 = df1.iloc[:-20]
df1 = df1.reset_index(drop=False)

df2 = pd.DataFrame(output, columns = ['Pred Adj Close']).astype(float)

# %%
df2
# Out:
#      Pred Adj Close
# 0       3350.623779
# 1       3344.800781
# 2       3338.470703
# 3       3335.099854
# 4       3337.173340
# ..              ...
# 247     3793.379639
# 248     3799.786621
# 249     3805.621826
# 250     3806.728760
# 251     3804.543701
#
# [252 rows x 1 columns]

# %%
df = df1.join(df2)
df = df.set_index('Date')

# %%
df
# Out:
#               Adj Close  Pred Adj Close
# Date
# 2020-01-02  3257.850098     3350.623779
# 2020-01-03  3234.850098     3344.800781
# 2020-01-06  3246.280029     3338.470703
# 2020-01-07  3237.179932     3335.099854
# 2020-01-08  3253.050049     3337.173340
# ...                 ...             ...
# 2020-12-23  3690.010010     3793.379639
# 2020-12-24  3703.060059     3799.786621
# 2020-12-28  3735.360107     3805.621826
# 2020-12-29  3727.040039     3806.728760
# 2020-12-30  3732.040039     3804.543701
#
# [252 rows x 2 columns]

# %% [markdown]
# Results

# %%
#plotting of graphs - Full Overview

train = trainingData['Adj Close']
real = df['Adj Close']
pred = df['Pred Adj Close']
plt.figure(figsize=(10,10))
plt.title('SP500 Actual vs Predicted (01/01/2020 - 30/12/2020)')
plt.xlabel('Date')
plt.ylabel('Adj Close Price ($)')
plt.plot(train)
plt.plot(real)
plt.plot(pred)
plt.legend(['Actual Pre-Training', 'Actual Post-Training','LSTM Prediction'], loc='lower right')
plt.xticks()
plt.show()

#plotting of graphs - Full Overview
real = df['Adj Close']
pred = df['Pred Adj Close']
plt.figure(figsize=(10,10))
plt.title('SP500 Actual vs Predicted (01/01/2020 - 30/12/2020)')
plt.xlabel('Date')
plt.ylabel('Adj Close Price ($)')
plt.plot(real)
plt.plot(pred)
plt.legend(['Actual Post-Training','LSTM Prediction'], loc='lower right')
plt.xticks()
plt.show()
