# %% [markdown]
# Import neccessary libraries

# %%
pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np
import yfinance as yf

import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit



import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# --------------
# Data taken from 2019-2009 (20 Year Period)
#
# 2020 will only be presented once testing is finalized.

# %%
#Downloading of data from Yahoo Finance which will be used for model training
end = '2019-12-31'
start = '1999-01-02'

trainingData = yf.download('^GSPC', start=start, end=end)
trainingData.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1999-01-04  1229.229980  1248.810059  1219.099976  1228.099976  1228.099976
# 1999-01-05  1228.099976  1246.109985  1228.099976  1244.780029  1244.780029
# 1999-01-06  1244.780029  1272.500000  1244.780029  1272.339966  1272.339966
# 1999-01-07  1272.339966  1272.339966  1257.680054  1269.729980  1269.729980
# 1999-01-08  1269.729980  1278.239990  1261.819946  1275.089966  1275.089966
#
#                Volume
# Date
# 1999-01-04  877000000
# 1999-01-05  775000000
# 1999-01-06  986900000
# 1999-01-07  863000000
# 1999-01-08  937800000

# %%
#Downloading of data from Yahoo Finance which will be used for model testing
end = '2024-01-31'
start = '2020-01-02'

testingData = yf.download('^GSPC', start=start, end=end)
testingData.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3257.850098
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3234.850098
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3246.280029
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3237.179932
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3253.050049
#
#                 Volume
# Date
# 2020-01-02  3459930000
# 2020-01-03  3484700000
# 2020-01-06  3702460000
# 2020-01-07  3435910000
# 2020-01-08  3726840000

# %%
#Prediction will take place on Adj Close price, therefore we must isolate Adj Close.
trainprice = trainingData['Adj Close']
trainData = trainprice.values

testprice = testingData['Adj Close']
testData = testprice.values

# %%
trainData
# Out:
# array([1228.09997559, 1244.7800293 , 1272.33996582, ..., 3239.90991211,
#        3240.02001953, 3221.29003906])

# %% [markdown]
# Plotting of High vs Low

# %%
plt.figure(figsize=(10,10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.gca().yaxis.set_major_locator(mdates.DayLocator(interval=200))

plt.plot(trainingData.index, trainingData['Adj Close'], label='Train Data Actual Adj Close')
plt.plot(testingData.index, testingData['Adj Close'], label='Test Data Actual Adj Close')
plt.xlabel('Date')
plt.ylabel('USD')
plt.legend()
plt.gcf().autofmt_xdate()
plt.show()

# %%
sc = MinMaxScaler(feature_range=(0,1))
trainDataScaled = sc.fit_transform(trainData.reshape(-1, 1))
testDataScaled = sc.fit_transform(testData.reshape(-1, 1))

# %%
n_steps = 20

xTrain, yTrain = [], []

for i in range(n_steps, len(trainDataScaled)):
    xTrain.append(trainDataScaled[i-n_steps:i, 0])
    yTrain.append(trainDataScaled[i, 0])
      
xTrain, yTrain = np.array(xTrain), np.array(yTrain)
xTrain = np.reshape(xTrain, (xTrain.shape[0], xTrain.shape[1], 1))

# %%
#LSTM Model

model = Sequential()

#Layer 1
model.add(LSTM(units=200,return_sequences=True,input_shape=(xTrain.shape[1], 1)))
model.add(Dropout(0.2))
#Layer 2
model.add(LSTM(units=200,return_sequences=True))
model.add(Dropout(0.2))
#Layer 3
model.add(LSTM(units=200,return_sequences=True))
model.add(Dropout(0.2))
#Layer 4
model.add(LSTM(units=200, return_sequences=False))
model.add(Dropout(0.2))
#Layer 5
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error', metrics=[RootMeanSquaredError(), MeanAbsoluteError()])
model.summary()

#Early stopping parameters to stop unnecessary training
earlyStopping = EarlyStopping(
    monitor='val_root_mean_squared_error',
    patience=15,
    mode='min',
    min_delta = 0.000001
)

# %%
#Method to plot the training metric vs validation metric
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics)
    plt.plot(epochs, val_metrics)
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()

# %%
#Evaluation of model to confirm if parameters set above are valid
eval = model.evaluate(xTrain, yTrain)
# Out:
# WARNING:tensorflow:From d:\Users\Andrea Bugeja\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 165/165 [==============================] - 4s 14ms/step - loss: 0.1658 - root_mean_squared_error: 0.4072 - mean_absolute_error: 0.3419

# %%
len(xTrain)
# Out:
# 5262

# %%
log = model.fit(
    xTrain,
    yTrain,
    epochs=100,
    batch_size=128, 
    validation_split = 0.25, 
    verbose=1, 
    callbacks=[earlyStopping], 
    shuffle=False)
plot_metric(log, 'root_mean_squared_error')
# Out:
# Epoch 1/100
# 31/31 [==============================] - 9s 111ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - mean_absolute_error: 0.0710 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0925 - val_mean_absolute_error: 0.0744
# Epoch 2/100
# 31/31 [==============================] - 3s 108ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - mean_absolute_error: 0.0910 - val_loss: 0.1023 - val_root_mean_squared_error: 0.3198 - val_mean_absolute_error: 0.3016
# Epoch 3/100
# 31/31 [==============================] - 3s 111ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - mean_absolute_error: 0.0844 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0740 - val_mean_absolute_error: 0.0613
# Epoch 4/100
# 31/31 [==============================] - 3s 112ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - mean_absolute_error: 0.0855 - val_loss: 0.1194 - val_root_mean_squared_error: 0.3455 - val_mean_absolute_error: 0.3224
# Epoch 5/100
# 31/31 [==============================] - 3s 106ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - mean_absolute_error: 0.0921 - val_loss: 0.1114 - val_root_mean_squared_error: 0.3338 - val_mean_absolute_error: 0.3138
# Epoch 6/100
# 31/31 [==============================] - 3s 110ms/step - loss: 0.0086 - root_mean_squared_error: 0.0928 - mean_absolute_error: 0.0776 - val_loss: 0.1064 - val_root_mean_squared_error: 0.3262 - val_mean_absolute_error: 0.3085
# Epoch 7/100
# 31/31 [==============================] - 3s 107ms/step - loss: 0.0026 - root_mean_squared_error: 0.0513 - mean_absolute_error: 0.0396 - val_loss: 9.6391e-04 - val_root_mean_squared_error: 0.0310 - val_mean_absolute_error: 0.0248
# Epoch 8/100
# 31/31 [==============================] - 3s 106ms/step - loss: 0.0017 - root_mean_squared_error: 0.0408 - mean_absolute_error: 0.0326 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0692 - val_mean_absolute_error: 0.0657
# Epoch 9/100
# 31/31 [==============================] - 3s 106ms/step - loss: 0.0032 - root_mean_squared_error: 0.0564 - mean_absolute_error: 0.0456 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1147 - val_mean_absolute_error: 0.1038
# Epoch 10/100
# 31/31 [==============================] - 3s 104ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - mean_absolute_error: 0.0286 - val_loss: 5.6545e-04 - val_root_mean_squared_error: 0.0238 - val_mean_absolute_error: 0.0165
# Epoch 11/100
# 31/31 [==============================] - 3s 105ms/step - loss: 4.0025e-04 - root_mean_squared_error: 0.0200 - mean_absolute_error: 0.0153 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0332 - val_mean_absolute_error: 0.0263
# Epoch 12/100
# 31/31 [==============================] - 3s 107ms/step - loss: 3.3962e-04 - root_mean_squared_error: 0.0184 - mean_absolute_error: 0.0140 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347 - val_mean_absolute_error: 0.0259
# Epoch 13/100
# 31/31 [==============================] - 3s 109ms/step - loss: 4.1503e-04 - root_mean_squared_error: 0.0204 - mean_absolute_error: 0.0155 - val_loss: 8.6261e-04 - val_root_mean_squared_error: 0.0294 - val_mean_absolute_error: 0.0226
# Epoch 14/100
# 31/31 [==============================] - 3s 104ms/step - loss: 4.8627e-04 - root_mean_squared_error: 0.0221 - mean_absolute_error: 0.0169 - val_loss: 9.4726e-04 - val_root_mean_squared_error: 0.0308 - val_mean_absolute_error: 0.0236
# Epoch 15/100
# 31/31 [==============================] - 3s 98ms/step - loss: 5.4536e-04 - root_mean_squared_error: 0.0234 - mean_absolute_error: 0.0180 - val_loss: 9.6008e-04 - val_root_mean_squared_error: 0.0310 - val_mean_absolute_error: 0.0244
# Epoch 16/100
# 31/31 [==============================] - 3s 92ms/step - loss: 6.5365e-04 - root_mean_squared_error: 0.0256 - mean_absolute_error: 0.0196 - val_loss: 9.2801e-04 - val_root_mean_squared_error: 0.0305 - val_mean_absolute_error: 0.0247
# Epoch 17/100
# 31/31 [==============================] - 3s 95ms/step - loss: 8.1569e-04 - root_mean_squared_error: 0.0286 - mean_absolute_error: 0.0224 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0335 - val_mean_absolute_error: 0.0286
# Epoch 18/100
# 31/31 [==============================] - 3s 92ms/step - loss: 0.0013 - root_mean_squared_error: 0.0358 - mean_absolute_error: 0.0276 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0457 - val_mean_absolute_error: 0.0409
# Epoch 19/100
# 31/31 [==============================] - 3s 91ms/step - loss: 0.0024 - root_mean_squared_error: 0.0486 - mean_absolute_error: 0.0380 - val_loss: 6.2473e-04 - val_root_mean_squared_error: 0.0250 - val_mean_absolute_error: 0.0190
# Epoch 20/100
# 31/31 [==============================] - 3s 89ms/step - loss: 0.0024 - root_mean_squared_error: 0.0486 - mean_absolute_error: 0.0398 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1065 - val_mean_absolute_error: 0.0971
# Epoch 21/100
# 31/31 [==============================] - 3s 92ms/step - loss: 8.9336e-04 - root_mean_squared_error: 0.0299 - mean_absolute_error: 0.0223 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.0573
# Epoch 22/100
# 31/31 [==============================] - 3s 98ms/step - loss: 5.1125e-04 - root_mean_squared_error: 0.0226 - mean_absolute_error: 0.0177 - val_loss: 9.1932e-04 - val_root_mean_squared_error: 0.0303 - val_mean_absolute_error: 0.0264
# Epoch 23/100
# 31/31 [==============================] - 3s 91ms/step - loss: 4.0358e-04 - root_mean_squared_error: 0.0201 - mean_absolute_error: 0.0156 - val_loss: 8.2036e-04 - val_root_mean_squared_error: 0.0286 - val_mean_absolute_error: 0.0215
# Epoch 24/100
# 31/31 [==============================] - 3s 91ms/step - loss: 3.6228e-04 - root_mean_squared_error: 0.0190 - mean_absolute_error: 0.0145 - val_loss: 5.8702e-04 - val_root_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.0182
# Epoch 25/100
# 31/31 [==============================] - 3s 92ms/step - loss: 3.6743e-04 - root_mean_squared_error: 0.0192 - mean_absolute_error: 0.0151 - val_loss: 6.8686e-04 - val_root_mean_squared_error: 0.0262 - val_mean_absolute_error: 0.0202

# %%
n_steps = 20

xTest = []
yTest = []

for i in range(n_steps, len(testDataScaled)):
    xTest.append(testDataScaled[i-n_steps:i, 0])
    yTest.append(testDataScaled[i, 0])
      
xTest, yTest = np.array(xTest), np.array(yTest)
xTest = np.reshape(xTest, (xTest.shape[0], xTest.shape[1], 1))

# %%
predictions = model.predict(xTest) #Prediction on Data using trained model
output = sc.inverse_transform(predictions)
rmse = np.sqrt(mean_squared_error(predictions, yTest)) #Calculating of RMSE
rmse
# Out:
# 32/32 [==============================] - 2s 12ms/step
# 0.044337103165647505

# %%
eval = model.evaluate(xTest, yTest) #Calculating of additional metrics (Loss, RMSE, MAE)
# Out:
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0020 - root_mean_squared_error: 0.0443 - mean_absolute_error: 0.0339

# %% [markdown]
# The following cells are the joining of the actual data + prediction into a single DF

# %%
df1 = pd.DataFrame(testingData['Adj Close']).astype(float)
df1 = df1.iloc[:-20]
df1 = df1.reset_index(drop=False)

df2 = pd.DataFrame(output, columns = ['Pred Adj Close']).astype(float)

# %%
df2
# Out:
#       Pred Adj Close
# 0        3349.508789
# 1        3345.477295
# 2        3340.313232
# 3        3335.586426
# 4        3333.168701
# ...              ...
# 997      4620.336914
# 998      4622.604492
# 999      4625.681152
# 1000     4630.299805
# 1001     4636.506836
#
# [1002 rows x 1 columns]

# %%
df = df1.join(df2)
df = df.set_index('Date')

# %%
df
# Out:
#               Adj Close  Pred Adj Close
# Date
# 2020-01-02  3257.850098     3349.508789
# 2020-01-03  3234.850098     3345.477295
# 2020-01-06  3246.280029     3340.313232
# 2020-01-07  3237.179932     3335.586426
# 2020-01-08  3253.050049     3333.168701
# ...                 ...             ...
# 2023-12-18  4740.560059     4620.336914
# 2023-12-19  4768.370117     4622.604492
# 2023-12-20  4698.350098     4625.681152
# 2023-12-21  4746.750000     4630.299805
# 2023-12-22  4754.629883     4636.506836
#
# [1002 rows x 2 columns]

# %% [markdown]
# Results

# %%
#plotting of graphs - Full Overview

train = trainingData['Adj Close']
real = df['Adj Close']
pred = df['Pred Adj Close']
plt.figure(figsize=(10,10))
plt.title('SP500 Actual vs Predicted (01/01/2020 - 01/01/2024)')
plt.xlabel('Date')
plt.ylabel('Adj Close Price ($)')
plt.plot(train)
plt.plot(real)
plt.plot(pred)
plt.legend(['Actual Pre-Training', 'Actual Post-Training','LSTM Prediction'], loc='lower right')
plt.xticks()
plt.show()

#plotting of graphs - Full Overview
real = df['Adj Close']
pred = df['Pred Adj Close']
plt.figure(figsize=(10,10))
plt.title('SP500 Actual vs Predicted (01/01/2020 - 01/01/2024)')
plt.xlabel('Date')
plt.ylabel('Adj Close Price ($)')
plt.plot(real)
plt.plot(pred)
plt.legend(['Actual Post-Training','LSTM Prediction'], loc='lower right')
plt.xticks()
plt.show()
